# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloAndree/Python_PA/blob/main/%5BStudentView%5D_Lab_1_Adquisicio%CC%81n_Datos_via_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Laboratorio: Adquisición de Datos**
#
# El objetivo de esta sesión es aprender diferentes técnicas en Python para la adquisición de datos.

# %% [markdown]
# ## **I. Adquisición de Datos a través de APIs sin Autenticación**

# %% [markdown]
# ### **Paso 0:** Cargar las librerías

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ***Random User Generator API:*** esta es una gran herramienta para [generar datos de usuarios aleatorios](https://randomuser.me/). Puede usarlo para generar cualquier cantidad de usuarios aleatorios y datos asociados, y también puede especificar el género, la nacionalidad y muchos otros filtros que pueden ser realmente útiles al probar aplicaciones o, en este caso, API.

# %% [markdown]
# ### **Paso 1:** Recolectar datos desde un Web API

# %%
#Hacemos el request al servidor
response = requests.get("https://randomuser.me/api/")
response
# Out:
# <Response [200]>

# %% [markdown]
# Información del Objeto `Request`:

# %%
#La función del request
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Date': 'Wed, 23 Oct 2024 21:56:04 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache', 'ETag': 'W/"47f-S4eaSQraJMQ2mUmy/yadconnbrc"', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'cf-cache-status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v4?s=vqKVrAxoneG2dOr9Yf2WKnw0IbA0ipGxekGkZH7tAtJ4GIfKFMaS%2BuD7rFJPdBm0LF%2FxEnmbyHEuwuF%2Bsk9yHoGUVE70BXOcQofqQbvfSsLs3MXMVKDyqiiNRTrfziiY"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '8d74f99558dedf10-SEA', 'alt-svc': 'h3=":443"; ma=86400', 'server-timing': 'cfL4;desc="?proto=TCP&rtt=7314&sent=4&recv=6&lost=0&retrans=0&sent_bytes=2848&recv_bytes=767&delivery_rate=409502&cwnd=233&unsent_bytes=0&cid=f5216fbdc4b419a9&ts=95&x=0"'}

# %%
#Recuperar la url

# %% [markdown]
# ***HTTP Headers***
#
# *   `Accept` Tipo de contenido el cliente puede aceptar
# *   `Content-Type` Tipo de contenido que responderá el servidor
# *   `User-Agent` Software que el cliente esta usando para comunicarse con el servidor
# *   `Server` Software que el servidor esta. usando para comunicarse con el cliente
# *   `Authentication` Quién esta llamando el API y sus credenciales.
#
# Y algunas más ...

# %%
#Http Headers

# %% [markdown]
# Información del objeto `Response`:

# %%
#Revisar status code
response.status_code
# Out:
# 200

# %%
#Revisar headers

# %% [markdown]
# El header `Content-Type` es muy importante para saber cómo manejar una respuesta y qué hacer con su contenido. Los tipos de contenido aceptables son Json, audio, video, fuentes y más.

# %%
# TO DO
response.headers.get("Content-Type")
# Out:
# 'application/json; charset=utf-8'

# %% [markdown]
# Para visualizar el contenido (los datos)
#
# *   `.text` Retorna la respuesta en formato Unicode
# *   `.content` Retorna la respuesta en bytes

# %%
# TO DO - TEXTO PURO
response.text
# Out:
# '{"results":[{"gender":"female","name":{"title":"Mrs","first":"Abigail","last":"Gagnon"},"location":{"street":{"number":1232,"name":"Park Rd"},"city":"Trenton","state":"Prince Edward Island","country":"Canada","postcode":"E2O 2K1","coordinates":{"latitude":"-69.0418","longitude":"50.2919"},"timezone":{"offset":"+5:00","description":"Ekaterinburg, Islamabad, Karachi, Tashkent"}},"email":"abigail.gagnon@example.com","login":{"uuid":"058a1aec-8620-4018-a27e-0bab9ba83080","username":"tinybear719","password":"hobbit","salt":"AjccfHyi","md5":"a7a07e04fb20be403d5cddf86d75bba9","sha1":"09cbf281fe78aca5d63287eff400088adcc639a4","sha256":"4b9a2e0c5cee2e630aacb5538660551bcd823b31d04a7849596fee8d79b0553f"},"dob":{"date":"1980-02-19T04:27:50.182Z","age":44},"registered":{"date":"2016-07-06T10:14:41.514Z","age":8},"phone":"T65 G05-0699","cell":"H81 P88-4788","id":{"name":"SIN","value":"650239486"},"picture":{"large":"https://randomuser.me/api/portraits/women/54.jpg","medium":"https://randomuser.me
# ...

# %%
#Visualizar los datos
response.content
# Out:
# b'{"results":[{"gender":"male","name":{"title":"Mr","first":"Idhant","last":"Rao"},"location":{"street":{"number":2744,"name":"Shanmugham Rd"},"city":"Saharanpur","state":"Mizoram","country":"India","postcode":44872,"coordinates":{"latitude":"6.4246","longitude":"-72.4311"},"timezone":{"offset":"+10:00","description":"Eastern Australia, Guam, Vladivostok"}},"email":"idhant.rao@example.com","login":{"uuid":"7bf4dca6-91d1-4283-b0ea-7b2068966a1b","username":"tinymouse510","password":"1007","salt":"Je2elHn8","md5":"824e84492c77f83fe871b930b3d1f3be","sha1":"f410653a19d372fbe79275e5c62ff8e0caa3328c","sha256":"a6f87a490f7bd15833e18c0c6c6aa934536bb7bcfee6b24fa6660b6e6595be2a"},"dob":{"date":"1983-09-09T18:40:58.503Z","age":41},"registered":{"date":"2005-04-13T21:10:02.102Z","age":19},"phone":"8564461688","cell":"8410991179","id":{"name":"UIDAI","value":"884689083110"},"picture":{"large":"https://randomuser.me/api/portraits/men/5.jpg","medium":"https://randomuser.me/api/portraits/med/men/5.jp
# ...

# %% [markdown]
# ### **Paso 2:** Decodificar un JSON data

# %% [markdown]
# Dado que el contenido es de formato JSON, podemos usar la función `.json()` que convierte la respuesta del API (bytes) en una estructura de datos Python (dictionario)

# %%
#Visualizar JSON format
data = response.json()
data
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Idhant', 'last': 'Rao'},
#    'location': {'street': {'number': 2744, 'name': 'Shanmugham Rd'},
#     'city': 'Saharanpur',
#     'state': 'Mizoram',
#     'country': 'India',
#     'postcode': 44872,
#     'coordinates': {'latitude': '6.4246', 'longitude': '-72.4311'},
#     'timezone': {'offset': '+10:00',
#      'description': 'Eastern Australia, Guam, Vladivostok'}},
#    'email': 'idhant.rao@example.com',
#    'login': {'uuid': '7bf4dca6-91d1-4283-b0ea-7b2068966a1b',
#     'username': 'tinymouse510',
#     'password': '1007',
#     'salt': 'Je2elHn8',
#     'md5': '824e84492c77f83fe871b930b3d1f3be',
#     'sha1': 'f410653a19d372fbe79275e5c62ff8e0caa3328c',
#     'sha256': 'a6f87a490f7bd15833e18c0c6c6aa934536bb7bcfee6b24fa6660b6e6595be2a'},
#    'dob': {'date': '1983-09-09T18:40:58.503Z', 'age': 41},
#    'registered': {'date': '2005-04-13T21:10:02.102Z', 'age': 19},
#    'phone': '8564461688',
# ...

# %%
data.keys()
# Out:
# dict_keys(['results', 'info'])

# %% [markdown]
# Generamos un dataframe a partir del json. Para ello usamos de la librería de Pandas la función `json_normalize()` que normaliza los datos JSON semiestructurados en un dataframe.

# %%
#TO DO
df = pd.json_normalize(data, "results")
df.head()
# Out:
#   gender                   email       phone        cell nat name.title  \
# 0   male  idhant.rao@example.com  8564461688  8410991179  IN         Mr
#
#   name.first name.last  location.street.number location.street.name  ...  \
# 0     Idhant       Rao                    2744        Shanmugham Rd  ...
#
#                                         login.sha256  \
# 0  a6f87a490f7bd15833e18c0c6c6aa934536bb7bcfee6b2...
#
#                    dob.date dob.age           registered.date registered.age  \
# 0  1983-09-09T18:40:58.503Z      41  2005-04-13T21:10:02.102Z             19
#
#   id.name      id.value                                  picture.large  \
# 0   UIDAI  884689083110  https://randomuser.me/api/portraits/men/5.jpg
#
#                                       picture.medium  \
# 0  https://randomuser.me/api/portraits/med/men/5.jpg
#
#                                    picture.thumbnail
# 0  https://randomuser.me/api/portraits/thumb/men/...
#
# [1 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender                          1 non-null      object
#  1   email                           1 non-null      object
#  2   phone                           1 non-null      object
#  3   cell                            1 non-null      object
#  4   nat                             1 non-null      object
#  5   name.title                      1 non-null      object
#  6   name.first                      1 non-null      object
#  7   name.last                       1 non-null      object
#  8   location.street.number          1 non-null      int64
#  9   location.street.name            1 non-null      object
#  10  location.city                   1 non-null      object
#  11  location.state                  1 non-null      object
# ...

# %% [markdown]
# ### **Paso 3:** Analizar datos de `n` personas
#
# Dado que ya sabemos hace un request, ahora extramos data de `n` personas. Para entender el dataset aplique métodos para explorar los datos

# %% [markdown]
# 1. Construye una función que extraiga del API `n` resultados.

# %%
#TO DO
def get_dataNUsers(n):
  url = "https://randomuser.me/api/"
  lista_data = []
  for i in range(n):
    response = requests.get(url)
    data = response.json()
    lista_data.append(data)

  df = pd.json_normalize(lista_data, "results")
  return df

# %%
def get_dataNUsers1(n):
  url = "https://randomuser.me/api/?results=" + str(n)
  response = requests.get(url)
  data = response.json()
  df = pd.json_normalize(data, "results")
  return df

# %% [markdown]
# 2. Explora el dataset

# %%
#TO DO
get_dataNUsers(5)
# Out:
#    gender                           email           phone            cell nat  \
# 0  female          zoe.wilson@example.com    X94 A16-1980    T95 F05-3090  CA
# 1    male         arnav.anand@example.com      7776944090      7175391162  IN
# 2    male       billy.pearson@example.com    071-534-1722    081-545-9926  IE
# 3  female     isabel.robinson@example.com  (332)-822-9084  (441)-588-6676  NZ
# 4    male  eberhardt.schlicht@example.com    0320-1573307    0176-0729555  DE
#
#   name.title name.first name.last  location.street.number  \
# 0         Ms        Zoe    Wilson                    7548
# 1         Mr      Arnav     Anand                    1426
# 2         Mr      Billy   Pearson                    4240
# 3        Mrs     Isabel  Robinson                     349
# 4         Mr  Eberhardt  Schlicht                    6263
#
#   location.street.name  ...  \
# 0    Concession Road 6  ...
# 1           Vellala St  ...
# 2          Tara Street  ...
# ...

# %%
get_dataNUsers1(5)
# Out:
#    gender                              email           phone            cell  \
# 0  female  stephanie.fitzsimmons@example.com    041-922-3971    081-985-3018
# 1  female         meera.vernekar@example.com      8860507896      8019889104
# 2    male               lee.king@example.com    031-849-4901    081-495-1336
# 3    male          cohen.edwards@example.com  (869)-567-5944  (263)-471-7367
# 4  female        ingeborg.dumont@example.com   078 475 13 34   077 380 40 98
#
#   nat    name.title name.first    name.last  location.street.number  \
# 0  IE          Miss  Stephanie  Fitzsimmons                    5235
# 1  IN           Mrs      Meera     Vernekar                     627
# 2  IE            Mr        Lee         King                    3849
# 3  NZ            Mr      Cohen      Edwards                    6846
# 4  CH  Mademoiselle   Ingeborg       Dumont                    1733
#
#   location.street.name  ...  \
# 0           Jones Road  ...
# 1             Camac St  ...
# ...

# %% [markdown]
# ## **II. Adquisición de Datos a través de APIs con Autenticación**

# %% [markdown]
# Los enfoques de **autenticación** van desde lo más simple y directo, como los que usan claves API (API keys) o autenticación básica, hasta técnicas mucho más complejas y seguras, como `OAuth`.
#
# Por lo general, llamar a una API sin credenciales o con las incorrectas devolverá un status code: `401 No autorizado` o `403 Prohibido`.

# %% [markdown]
# **API Keys**
#
# Estas claves se utilizan para identificarse como usuario o cliente de la API y para rastrear su uso de la API. Las claves API generalmente se envían como un encabezado de solicitud (request header) o como un parámetro de consulta (query).

# %% [markdown]
# **API de la NASA:** una de las mejores colecciones de [API](https://apod.nasa.gov/apod/astropix.html) disponibles públicamente es la proporcionada por la NASA. Se puede obtener la imagen astronómica del día o imágenes tomadas por la Cámara de imágenes policromáticas de la Tierra (EPIC), entre otras.

# %% [markdown]
# ### **Paso 1:** Definir la url

# %%
#Definimos la url
url = "https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos"

# %% [markdown]
# ### **Paso 2:** Construir los parámetros y request al servidor

# %%
#Nasa otorga DEMO_KEY como key por default
api_key = "DEMO_KEY"
#Construir los párametros de consulta
query_params = {"api_key": api_key, "earth_date": "2023-10-03"}
#Hacer el request
response = requests.get(url, params=query_params)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### **Paso 3:** Convertir la respuesta a `json`

# %%
#Recepcionar como dictionary
#TO DO
data = response.json()
data
# Out:
# {'photos': [{'id': 1196094,
#    'sol': 3966,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03966/opgs/edr/fcam/FLB_749585826EDR_F1050106FHAZ00337M_.JPG',
#    'earth_date': '2023-10-03',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
# ...

# %%
data.keys()
# Out:
# dict_keys(['photos'])

# %% [markdown]
# ### **Paso 4:** Crear dataframe con los datos recolectados

# %%
# Extraer los datos y guardarlos en un dataframe
df = pd.json_normalize(data, 'photos')
df.head()
# Out:
#         id   sol                                            img_src  \
# 0  1196094  3966  https://mars.nasa.gov/msl-raw-images/proj/msl/...
# 1  1196095  3966  https://mars.nasa.gov/msl-raw-images/proj/msl/...
# 2  1196096  3966  https://mars.nasa.gov/msl-raw-images/proj/msl/...
# 3  1196097  3966  https://mars.nasa.gov/msl-raw-images/proj/msl/...
# 4  1196098  3966  https://mars.nasa.gov/msl-raw-images/proj/msl/...
#
#    earth_date  camera.id camera.name  camera.rover_id  \
# 0  2023-10-03         20        FHAZ                5
# 1  2023-10-03         20        FHAZ                5
# 2  2023-10-03         20        FHAZ                5
# 3  2023-10-03         20        FHAZ                5
# 4  2023-10-03         20        FHAZ                5
#
#                 camera.full_name  rover.id rover.name rover.landing_date  \
# 0  Front Hazard Avoidance Camera         5  Curiosity         2012-08-06
# 1  Front Hazard Avoidance Camera         5  Curiosity         2012-08-06
# ...

# %% [markdown]
# ## Guardar el nuevo dataframe

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df.to_csv("DataNasa031023.csv",index=False)

# %%
# !cp DataNasa031023.csv "drive/My Drive/"
